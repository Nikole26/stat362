# %% [raw]
# ---
# title: "Poetry: A Tool for Managing Python Environments and Dependencies"
# number-sections: true
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     self-contained: false
# jupyter: python3
# ---

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.11.9 (v3.11.9:de54cf5be3, Apr  2 2024, 07:12:50) [Clang 13.0.0 (clang-1300.0.29.30)]
# /Users/nikolemonterocervantes/Documents/stat_362/.venv/bin/python

# %% [markdown]
# ## Poetry: package management initialization
#
# 1. **Go to your project folder**
#    ```bash
#    cd <project-folder>
# 2.**(One-time) Put the venv inside the project**
#
#    ```bash
#    poetry config virtualenvs.in-project true
#    ```
# 3. **Initialize Poetry**
#    ```bash
#    poetry add requests pandas numpy xgboost
#    ```
# **This:**
# - updates `pyproject.toml` with dependencies
# - creates/updates `poetry.lock`
# - creates the virtual environment (first time)

# %% [markdown]
# 5. Activate the environment
#
# - **macOS/Linux (when using in-project venv):**
#
#     ```bash
#     source .venv/bin/activate
#     ```
#
# - **Windows (PowerShell/CMD, in-project venv):**
#
#     ```bash
#     .venv\Scripts\activate
#     ```

# %% [markdown]
# 1. **Run Commands**
#
#    ```bash
#     poetry run python -V
#     poetry run jupyter lab
#     ```
#
# 2. **Expected layout**
#    ```text
#    stat362/
#    ├── pyproject.toml    # Poetry configuration & dependencies
#    ├── poetry.lock       # Locked dependency versions
#    ├── .venv/            # Virtual environment (if configured)
#    └── homeworks/
#    └── quizzess/
#    └── project/
#    └── Lectures/
#    ```

# %% [markdown]
# ## Poetry Package Management Cheat Sheet
#
# ### Automatic (recommended)
#
# #### Add a Package
#
# ```bash
# poetry add <package>
# ```
# Updates both `pyproject.toml` and `poetry.lock`
#
# #### Remove a Package
#
# ```bash
# poetry remove <package>
# ```
# Also updates both `pyproject.toml` and `poetry.lock`

# %% [markdown]
# ### Manual Version Editing Workflow
#
# If you manually edited versions in `pyproject.toml`:
#
# Step 1: Validate the file
#
# ```bash
# poetry check
# ```
#
# Step 2: Update lock file (choose one)
#
# ```bash
# # Re-resolve using current constraints
# poetry lock --no-update
#
# # OR: Refresh to latest within your version ranges
# poetry update [<package>]
#
# Step 3: Install from lockfile
#
# ```bash
# # Standard installation
# poetry install
#
# # Dependencies only (skip installing current project)
# poetry install --no-root
# ```
#
# #### Understanding `--no-root`
#
# - **Don’t install the current project** (“root package”).
# - Use this only if you don’t need:
#   - `import your_project`
#   - Any scripts defined in `[tool.poetry.scripts]`

# %% [markdown]
# #### Best Practice Tip
#
# - ✅ **Prefer** `poetry add/remove` **over hand-editing**.
#
# If you do hand-edit, always follow the sequence:
#
# ```bash
# poetry check            # validate pyproject.toml
# poetry lock --no-update # re-resolve with current constraints
# poetry install          # install from the lockfile
# ```

# %% [markdown]
# ## Install Existing Dependencies
#
# Step 1: If you have an existing `pyproject.toml`, install project dependencies (from the folder containing `pyproject.toml`):
#
# ```bash
# poetry install  --no-root
# ```

# %% [markdown]
# Step 2: Verify the Python interpreter:
#
# ```bash
# poetry run which python
# ```
#
# This should point to the `.venv` folder under your project root.
#
# Step 3: Restart VS Code and select the Python interpreter from .venv for the best experience.

# %% [markdown]
# ## Useful poetry commands

# %%
# !poetry  show --tree
# Out:
# accelerate 1.8.0 Accelerate
# ├── huggingface-hub >=0.21.0
# │   ├── filelock *
# │   ├── fsspec >=2023.5.0
# │   │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │   │       ├── aiohappyeyeballs >=2.5.0
# │   │       ├── aiosignal >=1.1.2
# │   │       │   └── frozenlist >=1.1.0
# │   │       ├── async-timeout >=4.0,<6.0
# │   │       ├── attrs >=17.3.0
# │   │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │   │       ├── multidict >=4.5,<7.0
# │   │       │   └── typing-extensions >=4.1.0
# │   │       ├── propcache >=0.2.0
# │   │       └── yarl >=1.17.0,<2.0
# │   │           ├── idna >=2.0
# │   │           ├── multidict >=4.0 (circular dependency aborted here)
# │   │           └── propcache >=0.2.1 (circular dependency aborted here)
# │   ├── hf-xet >=1.1.2,<2.0.0
# │   ├── packaging >=20.9
# │   ├── pyyaml >=5.1
# │   ├── requests *
# │   │   ├── certifi >=2017.4.17
# │   │   ├── charset-normalizer >=2,<4
# │   │   ├── idna >=2.5,<4 (circular dependency aborted here)
# │   │   └── urllib3 >=1.21.1,<3
# │   ├── tqdm >=4.42.1
# │   │   └── colorama *
# │   └── typing-extensions >=3.7.4.3 (circular dependency aborted here)
# ├── numpy >=1.17,<3.0.0
# ├── packaging >=20.0
# ├── psutil *
# ├── pyyaml *
# ├── safetensors >=0.4.3
# └── torch >=2.0.0
#     ├── filelock *
#     ├── fsspec *
#     │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
#     │       ├── aiohappyeyeballs >=2.5.0
#     │       ├── aiosignal >=1.1.2
#     │       │   └── frozenlist >=1.1.0
#     │       ├── async-timeout >=4.0,<6.0
#     │       ├── attrs >=17.3.0
#     │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
#     │       ├── multidict >=4.5,<7.0
#     │       │   └── typing-extensions >=4.1.0
#     │       ├── propcache >=0.2.0
#     │       └── yarl >=1.17.0,<2.0
#     │           ├── idna >=2.0
#     │           ├── multidict >=4.0 (circular dependency aborted here)
#     │           └── propcache >=0.2.1 (circular dependency aborted here)
#     ├── jinja2 *
#     │   └── markupsafe >=2.0
#     ├── networkx *
#     ├── nvidia-cublas-cu12 12.6.4.1
#     ├── nvidia-cuda-cupti-cu12 12.6.80
#     ├── nvidia-cuda-nvrtc-cu12 12.6.77
#     ├── nvidia-cuda-runtime-cu12 12.6.77
#     ├── nvidia-cudnn-cu12 9.5.1.17
#     │   └── nvidia-cublas-cu12 * (circular dependency aborted here)
#     ├── nvidia-cufft-cu12 11.3.0.4
#     │   └── nvidia-nvjitlink-cu12 *
#     ├── nvidia-cufile-cu12 1.11.1.6
#     ├── nvidia-curand-cu12 10.3.7.77
#     ├── nvidia-cusolver-cu12 11.7.1.2
#     │   ├── nvidia-cublas-cu12 * (circular dependency aborted here)
#     │   ├── nvidia-cusparse-cu12 *
#     │   │   └── nvidia-nvjitlink-cu12 * (circular dependency aborted here)
#     │   └── nvidia-nvjitlink-cu12 * (circular dependency aborted here)
#     ├── nvidia-cusparse-cu12 12.5.4.2 (circular dependency aborted here)
#     ├── nvidia-cusparselt-cu12 0.6.3
#     ├── nvidia-nccl-cu12 2.26.2
#     ├── nvidia-nvjitlink-cu12 12.6.85 (circular dependency aborted here)
#     ├── nvidia-nvtx-cu12 12.6.77
#     ├── setuptools *
#     ├── sympy >=1.13.3
#     │   └── mpmath >=1.1.0,<1.4
#     ├── triton 3.3.1
#     │   └── setuptools >=40.8.0 (circular dependency aborted here)
#     └── typing-extensions >=4.10.0 (circular dependency aborted here)
# datasets 3.6.0 HuggingFace community-driven open-source library of datasets
# ├── dill >=0.3.0,<0.3.9
# ├── filelock *
# ├── fsspec >=2023.1.0,<=2025.3.0
# │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │       ├── aiohappyeyeballs >=2.5.0
# │       ├── aiosignal >=1.1.2
# │       │   └── frozenlist >=1.1.0
# │       ├── async-timeout >=4.0,<6.0
# │       ├── attrs >=17.3.0
# │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │       ├── multidict >=4.5,<7.0
# │       │   └── typing-extensions >=4.1.0
# │       ├── propcache >=0.2.0
# │       └── yarl >=1.17.0,<2.0
# │           ├── idna >=2.0
# │           ├── multidict >=4.0 (circular dependency aborted here)
# │           └── propcache >=0.2.1 (circular dependency aborted here)
# ├── huggingface-hub >=0.24.0
# │   ├── filelock *
# │   ├── fsspec >=2023.5.0
# │   │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │   │       ├── aiohappyeyeballs >=2.5.0
# │   │       ├── aiosignal >=1.1.2
# │   │       │   └── frozenlist >=1.1.0
# │   │       ├── async-timeout >=4.0,<6.0
# │   │       ├── attrs >=17.3.0
# │   │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │   │       ├── multidict >=4.5,<7.0
# │   │       │   └── typing-extensions >=4.1.0
# │   │       ├── propcache >=0.2.0
# │   │       └── yarl >=1.17.0,<2.0
# │   │           ├── idna >=2.0
# │   │           ├── multidict >=4.0 (circular dependency aborted here)
# │   │           └── propcache >=0.2.1 (circular dependency aborted here)
# │   ├── hf-xet >=1.1.2,<2.0.0
# │   ├── packaging >=20.9
# │   ├── pyyaml >=5.1
# │   ├── requests *
# │   │   ├── certifi >=2017.4.17
# │   │   ├── charset-normalizer >=2,<4
# │   │   ├── idna >=2.5,<4 (circular dependency aborted here)
# │   │   └── urllib3 >=1.21.1,<3
# │   ├── tqdm >=4.42.1
# │   │   └── colorama *
# │   └── typing-extensions >=3.7.4.3 (circular dependency aborted here)
# ├── multiprocess <0.70.17
# │   └── dill >=0.3.8
# ├── numpy >=1.17
# ├── packaging *
# ├── pandas *
# │   ├── numpy >=1.22.4
# │   ├── numpy >=1.23.2 (circular dependency aborted here)
# │   ├── numpy >=1.26.0 (circular dependency aborted here)
# │   ├── python-dateutil >=2.8.2
# │   │   └── six >=1.5
# │   ├── pytz >=2020.1
# │   └── tzdata >=2022.7
# ├── pyarrow >=15.0.0
# ├── pyyaml >=5.1
# ├── requests >=2.32.2
# │   ├── certifi >=2017.4.17
# │   ├── charset-normalizer >=2,<4
# │   ├── idna >=2.5,<4
# │   └── urllib3 >=1.21.1,<3
# ├── tqdm >=4.66.3
# │   └── colorama *
# └── xxhash *
# gensim 4.3.3 Python framework for fast Vector Space Modelling
# ├── numpy >=1.18.5,<2.0
# ├── scipy >=1.7.0,<1.14.0
# │   └── numpy >=1.22.4,<2.3
# └── smart-open >=1.8.1
#     └── wrapt *
# ipykernel 6.29.5 IPython Kernel for Jupyter
# ├── appnope *
# ├── comm >=0.1.1
# │   └── traitlets >=4
# ├── debugpy >=1.6.5
# ├── ipython >=7.23.1
# │   ├── colorama *
# │   ├── decorator *
# │   ├── exceptiongroup *
# │   │   └── typing-extensions >=4.6.0
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.6 (circular dependency aborted here)
# ├── jupyter-client >=6.1.12
# │   ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   │   ├── platformdirs >=2.5
# │   │   ├── pywin32 >=300
# │   │   └── traitlets >=5.3
# │   ├── python-dateutil >=2.8.2
# │   │   └── six >=1.5
# │   ├── pyzmq >=23.0
# │   │   └── cffi *
# │   │       └── pycparser *
# │   ├── tornado >=6.2
# │   └── traitlets >=5.3 (circular dependency aborted here)
# ├── jupyter-core >=4.12,<5.0.dev0 || >=5.1.dev0
# │   ├── platformdirs >=2.5
# │   ├── pywin32 >=300
# │   └── traitlets >=5.3
# ├── matplotlib-inline >=0.1
# │   └── traitlets *
# ├── nest-asyncio *
# ├── packaging *
# ├── psutil *
# ├── pyzmq >=24
# │   └── cffi *
# │       └── pycparser *
# ├── tornado >=6.1
# └── traitlets >=5.4.0
# ipywidgets 8.1.7 Jupyter interactive widgets
# ├── comm >=0.1.3
# │   └── traitlets >=4
# ├── ipython >=6.1.0
# │   ├── colorama *
# │   ├── decorator *
# │   ├── exceptiongroup *
# │   │   └── typing-extensions >=4.6.0
# │   ├── jedi >=0.16
# │   │   └── parso >=0.8.4,<0.9.0
# │   ├── matplotlib-inline *
# │   │   └── traitlets *
# │   ├── pexpect >4.3
# │   │   └── ptyprocess >=0.5
# │   ├── prompt-toolkit >=3.0.41,<3.1.0
# │   │   └── wcwidth *
# │   ├── pygments >=2.4.0
# │   ├── stack-data *
# │   │   ├── asttokens >=2.1.0
# │   │   ├── executing >=1.2.0
# │   │   └── pure-eval *
# │   ├── traitlets >=5.13.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.6 (circular dependency aborted here)
# ├── jupyterlab-widgets >=3.0.15,<3.1.0
# ├── traitlets >=4.3.1
# └── widgetsnbextension >=4.0.14,<4.1.0
# keras 3.11.3 Multi-backend Keras
# ├── absl-py *
# ├── h5py *
# │   └── numpy >=1.19.3
# ├── ml-dtypes *
# │   └── numpy >=1.26.0
# ├── namex *
# ├── numpy *
# ├── optree *
# │   └── typing-extensions >=4.6.0
# ├── packaging *
# └── rich *
#     ├── markdown-it-py >=2.2.0
#     │   └── mdurl >=0.1,<1.0
#     └── pygments >=2.13.0,<3.0.0
# matplotlib 3.10.3 Python plotting package
# ├── contourpy >=1.0.1
# │   └── numpy >=1.23
# ├── cycler >=0.10
# ├── fonttools >=4.22.0
# ├── kiwisolver >=1.3.1
# ├── numpy >=1.23
# ├── packaging >=20.0
# ├── pillow >=8
# ├── pyparsing >=2.3.1
# └── python-dateutil >=2.7
#     └── six >=1.5
# nltk 3.9.1 Natural Language Toolkit
# ├── click *
# │   └── colorama *
# ├── joblib *
# ├── regex >=2021.8.3
# └── tqdm *
#     └── colorama *
# plotly 6.2.0 An open-source interactive data visualization library for Python
# ├── narwhals >=1.15.1
# └── packaging *
# scikit-learn 1.7.0 A set of python modules for machine learning and data mining
# ├── joblib >=1.2.0
# ├── numpy >=1.22.0
# ├── scipy >=1.8.0
# │   └── numpy >=1.22.4,<2.3
# └── threadpoolctl >=3.1.0
# scipy 1.13.1 Fundamental algorithms for scientific computing in Python
# └── numpy >=1.22.4,<2.3
# seaborn 0.13.2 Statistical data visualization
# ├── matplotlib >=3.4,<3.6.1 || >3.6.1
# │   ├── contourpy >=1.0.1
# │   │   └── numpy >=1.23
# │   ├── cycler >=0.10
# │   ├── fonttools >=4.22.0
# │   ├── kiwisolver >=1.3.1
# │   ├── numpy >=1.23 (circular dependency aborted here)
# │   ├── packaging >=20.0
# │   ├── pillow >=8
# │   ├── pyparsing >=2.3.1
# │   └── python-dateutil >=2.7
# │       └── six >=1.5
# ├── numpy >=1.20,<1.24.0 || >1.24.0
# └── pandas >=1.2
#     ├── numpy >=1.22.4
#     ├── numpy >=1.23.2 (circular dependency aborted here)
#     ├── numpy >=1.26.0 (circular dependency aborted here)
#     ├── python-dateutil >=2.8.2
#     │   └── six >=1.5
#     ├── pytz >=2020.1
#     └── tzdata >=2022.7
# sentence-transformers 5.1.0 Embeddings, Retrieval, and Reranking
# ├── huggingface-hub >=0.20.0
# │   ├── filelock *
# │   ├── fsspec >=2023.5.0
# │   │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │   │       ├── aiohappyeyeballs >=2.5.0
# │   │       ├── aiosignal >=1.1.2
# │   │       │   └── frozenlist >=1.1.0
# │   │       ├── async-timeout >=4.0,<6.0
# │   │       ├── attrs >=17.3.0
# │   │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │   │       ├── multidict >=4.5,<7.0
# │   │       │   └── typing-extensions >=4.1.0
# │   │       ├── propcache >=0.2.0
# │   │       └── yarl >=1.17.0,<2.0
# │   │           ├── idna >=2.0
# │   │           ├── multidict >=4.0 (circular dependency aborted here)
# │   │           └── propcache >=0.2.1 (circular dependency aborted here)
# │   ├── hf-xet >=1.1.2,<2.0.0
# │   ├── packaging >=20.9
# │   ├── pyyaml >=5.1
# │   ├── requests *
# │   │   ├── certifi >=2017.4.17
# │   │   ├── charset-normalizer >=2,<4
# │   │   ├── idna >=2.5,<4 (circular dependency aborted here)
# │   │   └── urllib3 >=1.21.1,<3
# │   ├── tqdm >=4.42.1
# │   │   └── colorama *
# │   └── typing-extensions >=3.7.4.3 (circular dependency aborted here)
# ├── pillow *
# ├── scikit-learn *
# │   ├── joblib >=1.2.0
# │   ├── numpy >=1.22.0
# │   ├── scipy >=1.8.0
# │   │   └── numpy >=1.22.4,<2.3 (circular dependency aborted here)
# │   └── threadpoolctl >=3.1.0
# ├── scipy *
# │   └── numpy >=1.22.4,<2.3
# ├── torch >=1.11.0
# │   ├── filelock *
# │   ├── fsspec *
# │   │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │   │       ├── aiohappyeyeballs >=2.5.0
# │   │       ├── aiosignal >=1.1.2
# │   │       │   └── frozenlist >=1.1.0
# │   │       ├── async-timeout >=4.0,<6.0
# │   │       ├── attrs >=17.3.0
# │   │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │   │       ├── multidict >=4.5,<7.0
# │   │       │   └── typing-extensions >=4.1.0
# │   │       ├── propcache >=0.2.0
# │   │       └── yarl >=1.17.0,<2.0
# │   │           ├── idna >=2.0
# │   │           ├── multidict >=4.0 (circular dependency aborted here)
# │   │           └── propcache >=0.2.1 (circular dependency aborted here)
# │   ├── jinja2 *
# │   │   └── markupsafe >=2.0
# │   ├── networkx *
# │   ├── nvidia-cublas-cu12 12.6.4.1
# │   ├── nvidia-cuda-cupti-cu12 12.6.80
# │   ├── nvidia-cuda-nvrtc-cu12 12.6.77
# │   ├── nvidia-cuda-runtime-cu12 12.6.77
# │   ├── nvidia-cudnn-cu12 9.5.1.17
# │   │   └── nvidia-cublas-cu12 * (circular dependency aborted here)
# │   ├── nvidia-cufft-cu12 11.3.0.4
# │   │   └── nvidia-nvjitlink-cu12 *
# │   ├── nvidia-cufile-cu12 1.11.1.6
# │   ├── nvidia-curand-cu12 10.3.7.77
# │   ├── nvidia-cusolver-cu12 11.7.1.2
# │   │   ├── nvidia-cublas-cu12 * (circular dependency aborted here)
# │   │   ├── nvidia-cusparse-cu12 *
# │   │   │   └── nvidia-nvjitlink-cu12 * (circular dependency aborted here)
# │   │   └── nvidia-nvjitlink-cu12 * (circular dependency aborted here)
# │   ├── nvidia-cusparse-cu12 12.5.4.2 (circular dependency aborted here)
# │   ├── nvidia-cusparselt-cu12 0.6.3
# │   ├── nvidia-nccl-cu12 2.26.2
# │   ├── nvidia-nvjitlink-cu12 12.6.85 (circular dependency aborted here)
# │   ├── nvidia-nvtx-cu12 12.6.77
# │   ├── setuptools *
# │   ├── sympy >=1.13.3
# │   │   └── mpmath >=1.1.0,<1.4
# │   ├── triton 3.3.1
# │   │   └── setuptools >=40.8.0 (circular dependency aborted here)
# │   └── typing-extensions >=4.10.0 (circular dependency aborted here)
# ├── tqdm *
# │   └── colorama *
# ├── transformers >=4.41.0,<5.0.0
# │   ├── filelock *
# │   ├── huggingface-hub >=0.30.0,<1.0
# │   │   ├── filelock * (circular dependency aborted here)
# │   │   ├── fsspec >=2023.5.0
# │   │   │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │   │   │       ├── aiohappyeyeballs >=2.5.0
# │   │   │       ├── aiosignal >=1.1.2
# │   │   │       │   └── frozenlist >=1.1.0
# │   │   │       ├── async-timeout >=4.0,<6.0
# │   │   │       ├── attrs >=17.3.0
# │   │   │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │   │   │       ├── multidict >=4.5,<7.0
# │   │   │       │   └── typing-extensions >=4.1.0
# │   │   │       ├── propcache >=0.2.0
# │   │   │       └── yarl >=1.17.0,<2.0
# │   │   │           ├── idna >=2.0
# │   │   │           ├── multidict >=4.0 (circular dependency aborted here)
# │   │   │           └── propcache >=0.2.1 (circular dependency aborted here)
# │   │   ├── hf-xet >=1.1.2,<2.0.0
# │   │   ├── packaging >=20.9
# │   │   ├── pyyaml >=5.1
# │   │   ├── requests *
# │   │   │   ├── certifi >=2017.4.17
# │   │   │   ├── charset-normalizer >=2,<4
# │   │   │   ├── idna >=2.5,<4 (circular dependency aborted here)
# │   │   │   └── urllib3 >=1.21.1,<3
# │   │   ├── tqdm >=4.42.1
# │   │   │   └── colorama *
# │   │   └── typing-extensions >=3.7.4.3 (circular dependency aborted here)
# │   ├── numpy >=1.17
# │   ├── packaging >=20.0 (circular dependency aborted here)
# │   ├── pyyaml >=5.1 (circular dependency aborted here)
# │   ├── regex !=2019.12.17
# │   ├── requests * (circular dependency aborted here)
# │   ├── safetensors >=0.4.3
# │   ├── tokenizers >=0.21,<0.22
# │   │   └── huggingface-hub >=0.16.4,<1.0 (circular dependency aborted here)
# │   └── tqdm >=4.27 (circular dependency aborted here)
# └── typing-extensions >=4.5.0
# tensorboard 2.20.0 TensorBoard lets you watch Tensors Flow
# ├── absl-py >=0.4
# ├── grpcio >=1.48.2
# ├── markdown >=2.6.8
# ├── numpy >=1.12.0
# ├── packaging *
# ├── pillow *
# ├── protobuf >=3.19.6,<4.24.0 || >4.24.0
# ├── setuptools >=41.0.0
# ├── tensorboard-data-server >=0.7.0,<0.8.0
# └── werkzeug >=1.0.1
#     └── markupsafe >=2.1.1
# torch 2.7.1 Tensors and Dynamic neural networks in Python with strong GPU acceleration
# ├── filelock *
# ├── fsspec *
# │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │       ├── aiohappyeyeballs >=2.5.0
# │       ├── aiosignal >=1.1.2
# │       │   └── frozenlist >=1.1.0
# │       ├── async-timeout >=4.0,<6.0
# │       ├── attrs >=17.3.0
# │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │       ├── multidict >=4.5,<7.0
# │       │   └── typing-extensions >=4.1.0
# │       ├── propcache >=0.2.0
# │       └── yarl >=1.17.0,<2.0
# │           ├── idna >=2.0
# │           ├── multidict >=4.0 (circular dependency aborted here)
# │           └── propcache >=0.2.1 (circular dependency aborted here)
# ├── jinja2 *
# │   └── markupsafe >=2.0
# ├── networkx *
# ├── nvidia-cublas-cu12 12.6.4.1
# ├── nvidia-cuda-cupti-cu12 12.6.80
# ├── nvidia-cuda-nvrtc-cu12 12.6.77
# ├── nvidia-cuda-runtime-cu12 12.6.77
# ├── nvidia-cudnn-cu12 9.5.1.17
# │   └── nvidia-cublas-cu12 *
# ├── nvidia-cufft-cu12 11.3.0.4
# │   └── nvidia-nvjitlink-cu12 *
# ├── nvidia-cufile-cu12 1.11.1.6
# ├── nvidia-curand-cu12 10.3.7.77
# ├── nvidia-cusolver-cu12 11.7.1.2
# │   ├── nvidia-cublas-cu12 *
# │   ├── nvidia-cusparse-cu12 *
# │   │   └── nvidia-nvjitlink-cu12 *
# │   └── nvidia-nvjitlink-cu12 * (circular dependency aborted here)
# ├── nvidia-cusparse-cu12 12.5.4.2
# │   └── nvidia-nvjitlink-cu12 *
# ├── nvidia-cusparselt-cu12 0.6.3
# ├── nvidia-nccl-cu12 2.26.2
# ├── nvidia-nvjitlink-cu12 12.6.85
# ├── nvidia-nvtx-cu12 12.6.77
# ├── setuptools *
# ├── sympy >=1.13.3
# │   └── mpmath >=1.1.0,<1.4
# ├── triton 3.3.1
# │   └── setuptools >=40.8.0
# └── typing-extensions >=4.10.0
# torchsummary 1.5.1 Model summary in PyTorch similar to `model.summary()` in Keras
# transformers 4.52.4 State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# ├── filelock *
# ├── huggingface-hub >=0.30.0,<1.0
# │   ├── filelock *
# │   ├── fsspec >=2023.5.0
# │   │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │   │       ├── aiohappyeyeballs >=2.5.0
# │   │       ├── aiosignal >=1.1.2
# │   │       │   └── frozenlist >=1.1.0
# │   │       ├── async-timeout >=4.0,<6.0
# │   │       ├── attrs >=17.3.0
# │   │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │   │       ├── multidict >=4.5,<7.0
# │   │       │   └── typing-extensions >=4.1.0
# │   │       ├── propcache >=0.2.0
# │   │       └── yarl >=1.17.0,<2.0
# │   │           ├── idna >=2.0
# │   │           ├── multidict >=4.0 (circular dependency aborted here)
# │   │           └── propcache >=0.2.1 (circular dependency aborted here)
# │   ├── hf-xet >=1.1.2,<2.0.0
# │   ├── packaging >=20.9
# │   ├── pyyaml >=5.1
# │   ├── requests *
# │   │   ├── certifi >=2017.4.17
# │   │   ├── charset-normalizer >=2,<4
# │   │   ├── idna >=2.5,<4 (circular dependency aborted here)
# │   │   └── urllib3 >=1.21.1,<3
# │   ├── tqdm >=4.42.1
# │   │   └── colorama *
# │   └── typing-extensions >=3.7.4.3 (circular dependency aborted here)
# ├── numpy >=1.17
# ├── packaging >=20.0
# ├── pyyaml >=5.1
# ├── regex !=2019.12.17
# ├── requests *
# │   ├── certifi >=2017.4.17
# │   ├── charset-normalizer >=2,<4
# │   ├── idna >=2.5,<4
# │   └── urllib3 >=1.21.1,<3
# ├── safetensors >=0.4.3
# ├── tokenizers >=0.21,<0.22
# │   └── huggingface-hub >=0.16.4,<1.0
# │       ├── filelock *
# │       ├── fsspec >=2023.5.0
# │       │   └── aiohttp <4.0.0a0 || >4.0.0a0,<4.0.0a1 || >4.0.0a1
# │       │       ├── aiohappyeyeballs >=2.5.0
# │       │       ├── aiosignal >=1.1.2
# │       │       │   └── frozenlist >=1.1.0
# │       │       ├── async-timeout >=4.0,<6.0
# │       │       ├── attrs >=17.3.0
# │       │       ├── frozenlist >=1.1.1 (circular dependency aborted here)
# │       │       ├── multidict >=4.5,<7.0
# │       │       │   └── typing-extensions >=4.1.0
# │       │       ├── propcache >=0.2.0
# │       │       └── yarl >=1.17.0,<2.0
# │       │           ├── idna >=2.0
# │       │           ├── multidict >=4.0 (circular dependency aborted here)
# │       │           └── propcache >=0.2.1 (circular dependency aborted here)
# │       ├── hf-xet >=1.1.2,<2.0.0
# │       ├── packaging >=20.9
# │       ├── pyyaml >=5.1
# │       ├── requests *
# │       │   ├── certifi >=2017.4.17
# │       │   ├── charset-normalizer >=2,<4
# │       │   ├── idna >=2.5,<4 (circular dependency aborted here)
# │       │   └── urllib3 >=1.21.1,<3
# │       ├── tqdm >=4.42.1
# │       │   └── colorama *
# │       └── typing-extensions >=3.7.4.3 (circular dependency aborted here)
# └── tqdm >=4.27
#     └── colorama *
# umap-learn 0.5.7 Uniform Manifold Approximation and Projection
# ├── numba >=0.51.2
# │   ├── llvmlite ==0.44.*
# │   └── numpy >=1.24,<2.3
# ├── numpy >=1.17
# ├── pynndescent >=0.5
# │   ├── joblib >=0.11
# │   ├── llvmlite >=0.30
# │   ├── numba >=0.51.2
# │   │   ├── llvmlite ==0.44.* (circular dependency aborted here)
# │   │   └── numpy >=1.24,<2.3
# │   ├── scikit-learn >=0.18
# │   │   ├── joblib >=1.2.0 (circular dependency aborted here)
# │   │   ├── numpy >=1.22.0 (circular dependency aborted here)
# │   │   ├── scipy >=1.8.0
# │   │   │   └── numpy >=1.22.4,<2.3 (circular dependency aborted here)
# │   │   └── threadpoolctl >=3.1.0
# │   └── scipy >=1.0 (circular dependency aborted here)
# ├── scikit-learn >=0.22
# │   ├── joblib >=1.2.0
# │   ├── numpy >=1.22.0
# │   ├── scipy >=1.8.0
# │   │   └── numpy >=1.22.4,<2.3 (circular dependency aborted here)
# │   └── threadpoolctl >=3.1.0
# ├── scipy >=1.3.1
# │   └── numpy >=1.22.4,<2.3
# └── tqdm *
#     └── colorama *

# %%
# !poetry env info
# Out:
# Virtualenv
# Python:         3.11.9
# Implementation: CPython
# Path:           /Users/nikolemonterocervantes/Documents/stat_362/.venv
# Executable:     /Users/nikolemonterocervantes/Documents/stat_362/.venv/bin/python
# Valid:          True
#
# Base
# Platform:   darwin
# OS:         posix
# Python:     3.11.9
# Path:       /Library/Frameworks/Python.framework/Versions/3.11
# Executable: /Library/Frameworks/Python.framework/Versions/3.11/bin/python3.11

# %% [markdown]
# ## References & Resources
#
# - Poetry documentation (home): https://python-poetry.org/docs/
# - Basic usage (init, add/remove, install): https://python-poetry.org/docs/basic-usage/
# - CLI reference: `install`, `lock`, `update`:
#   - Install: https://python-poetry.org/docs/cli/#install
#   - Lock: https://python-poetry.org/docs/cli/#lock
#   - Update: https://python-poetry.org/docs/cli/#update
# - Managing environments (venvs, `poetry shell`): https://python-poetry.org/docs/managing-environments/
# - Configuration (`virtualenvs.in-project`): https://python-poetry.org/docs/configuration/#virtualenvsin-project
# - Dependency specification (version constraints): https://python-poetry.org/docs/dependency-specification/
# - Project scripts (`[tool.poetry.scripts]`): https://python-poetry.org/docs/pyproject/#scripts
# - Python Packaging User Guide (pip/venv fundamentals): https://packaging.python.org/en/latest/tutorials/installing-packages/
